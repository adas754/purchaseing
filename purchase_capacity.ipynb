# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %%
df=pd.read_csv("/content/CC_GENERAL.csv")

# %%
df.head()
# Out:
#   CUST_ID      BALANCE  BALANCE_FREQUENCY  PURCHASES  ONEOFF_PURCHASES  \
# 0  C10001    40.900749           0.818182      95.40              0.00
# 1  C10002  3202.467416           0.909091       0.00              0.00
# 2  C10003  2495.148862           1.000000     773.17            773.17
# 3  C10004  1666.670542           0.636364    1499.00           1499.00
# 4  C10005   817.714335           1.000000      16.00             16.00
#
#    INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# 0                    95.4      0.000000             0.166667
# 1                     0.0   6442.945483             0.000000
# 2                     0.0      0.000000             1.000000
# 3                     0.0    205.788017             0.083333
# 4                     0.0      0.000000             0.083333
#
#    ONEOFF_PURCHASES_FREQUENCY  PURCHASES_INSTALLMENTS_FREQUENCY  \
# 0                    0.000000                          0.083333
# ...

# %%
df.dtypes
# Out:
# CUST_ID                              object
# BALANCE                             float64
# BALANCE_FREQUENCY                   float64
# PURCHASES                           float64
# ONEOFF_PURCHASES                    float64
# INSTALLMENTS_PURCHASES              float64
# CASH_ADVANCE                        float64
# PURCHASES_FREQUENCY                 float64
# ONEOFF_PURCHASES_FREQUENCY          float64
# PURCHASES_INSTALLMENTS_FREQUENCY    float64
# CASH_ADVANCE_FREQUENCY              float64
# CASH_ADVANCE_TRX                      int64
# PURCHASES_TRX                         int64
# CREDIT_LIMIT                        float64
# PAYMENTS                            float64
# MINIMUM_PAYMENTS                    float64
# PRC_FULL_PAYMENT                    float64
# TENURE                                int64
# dtype: object

# %%
df.shape
# Out:
# (8950, 18)

# %%
df.values
# Out:
# array([['C10001', 40.900749, 0.818182, ..., 139.509787, 0.0, 12],
#        ['C10002', 3202.467416, 0.909091, ..., 1072.340217, 0.222222, 12],
#        ['C10003', 2495.148862, 1.0, ..., 627.284787, 0.0, 12],
#        ...,
#        ['C19188', 23.398673, 0.833333, ..., 82.418369, 0.25, 6],
#        ['C19189', 13.457564, 0.833333, ..., 55.755628, 0.25, 6],
#        ['C19190', 372.708075, 0.666667, ..., 88.288956, 0.0, 6]],
#       dtype=object)

# %%
df.describe()
# Out:
#             BALANCE  BALANCE_FREQUENCY     PURCHASES  ONEOFF_PURCHASES  \
# count   8950.000000        8950.000000   8950.000000       8950.000000
# mean    1564.474828           0.877271   1003.204834        592.437371
# std     2081.531879           0.236904   2136.634782       1659.887917
# min        0.000000           0.000000      0.000000          0.000000
# 25%      128.281915           0.888889     39.635000          0.000000
# 50%      873.385231           1.000000    361.280000         38.000000
# 75%     2054.140036           1.000000   1110.130000        577.405000
# max    19043.138560           1.000000  49039.570000      40761.250000
#
#        INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# count             8950.000000   8950.000000          8950.000000
# mean               411.067645    978.871112             0.490351
# std                904.338115   2097.163877             0.401371
# min                  0.000000      0.000000             0.000000
# ...

# %%
df.isnull().sum()
# Out:
# CUST_ID                             0
# BALANCE                             0
# BALANCE_FREQUENCY                   0
# PURCHASES                           0
# ONEOFF_PURCHASES                    0
# INSTALLMENTS_PURCHASES              0
# CASH_ADVANCE                        0
# PURCHASES_FREQUENCY                 0
# ONEOFF_PURCHASES_FREQUENCY          0
# PURCHASES_INSTALLMENTS_FREQUENCY    0
# CASH_ADVANCE_FREQUENCY              0
# CASH_ADVANCE_TRX                    0
# PURCHASES_TRX                       0
# CREDIT_LIMIT                        0
# PAYMENTS                            0
# MINIMUM_PAYMENTS                    0
# PRC_FULL_PAYMENT                    0
# TENURE                              0
# dtype: int64

# %%
df['MINIMUM_PAYMENTS'].fillna(df['MINIMUM_PAYMENTS'].mean(),inplace=True)
print("impute null value")
# Out:
# impute null value

# %%
df.dropna(inplace=True,axis=0)

# %%
df.shape
# Out:
# (8949, 18)

# %%
df.to_csv("final_csv",index=False)

# %%
df
# Out:
#      CUST_ID      BALANCE  BALANCE_FREQUENCY  PURCHASES  ONEOFF_PURCHASES  \
# 0     C10001    40.900749           0.818182      95.40              0.00
# 1     C10002  3202.467416           0.909091       0.00              0.00
# 2     C10003  2495.148862           1.000000     773.17            773.17
# 3     C10004  1666.670542           0.636364    1499.00           1499.00
# 4     C10005   817.714335           1.000000      16.00             16.00
# ...      ...          ...                ...        ...               ...
# 8945  C19186    28.493517           1.000000     291.12              0.00
# 8946  C19187    19.183215           1.000000     300.00              0.00
# 8947  C19188    23.398673           0.833333     144.40              0.00
# 8948  C19189    13.457564           0.833333       0.00              0.00
# 8949  C19190   372.708075           0.666667    1093.25           1093.25
#
#       INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# ...

# %%
df.drop("CUST_ID",inplace=True,axis=1)

# %%
print("column droped")
# Out:
# column droped

# %%
from scipy.stats import norm
graph=["BALANCE","BALANCE_FREQUENCY","PURCHASES","ONEOFF_PURCHASES","INSTALLMENTS_PURCHASES","CASH_ADVANCE",
       "PURCHASES_FREQUENCY","ONEOFF_PURCHASES_FREQUENCY","PURCHASES_INSTALLMENTS_FREQUENCY","CASH_ADVANCE_FREQUENCY","CASH_ADVANCE_TRX","PURCHASES_TRX","CREDIT_LIMIT","PAYMENTS","MINIMUM_PAYMENTS","PRC_FULL_PAYMENT","TENURE"
       ]
plt.figure(figsize=(15, 18))
for i in range(0, 17):
    plt.subplot(6,3,i+1)
    sns.distplot(df[graph[i]],fit=norm)
    plt.title(graph[i])
plt.tight_layout()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# ...

# %%
from sklearn.cluster import KMeans
from sklearn.preprocessing import MinMaxScaler
scaler=MinMaxScaler()
df_scaled=scaler.fit_transform(df)
df_scaled
# Out:
# array([[2.14779454e-03, 8.18182000e-01, 1.94536779e-03, ...,
#         1.82564563e-03, 0.00000000e+00, 1.00000000e+00],
#        [1.68169097e-01, 9.09091000e-01, 0.00000000e+00, ...,
#         1.40344791e-02, 2.22222000e-01, 1.00000000e+00],
#        [1.31026136e-01, 1.00000000e+00, 1.57662475e-02, ...,
#         8.20961806e-03, 0.00000000e+00, 1.00000000e+00],
#        ...,
#        [1.22871936e-03, 8.33333000e-01, 2.94456089e-03, ...,
#         1.07843629e-03, 2.50000000e-01, 0.00000000e+00],
#        [7.06688341e-04, 8.33333000e-01, 0.00000000e+00, ...,
#         7.29475795e-04, 2.50000000e-01, 0.00000000e+00],
#        [1.95717777e-02, 6.66667000e-01, 2.22932216e-02, ...,
#         1.15527021e-03, 0.00000000e+00, 0.00000000e+00]])

# %%
import joblib
joblib.dump(scaler,"Customer_Purchase_capability.pkl")
# Out:
# ['Customer_Purchase_capability.pkl']

# %%
inertia=[]
for i in range(1,11):
  kmeans=KMeans(
               n_clusters=i, init="k-means++",
                    n_init=10,
                    tol=1e-04, random_state=42
                    )
  kmeans.fit(df_scaled)
  inertia.append(kmeans.inertia_)
inertia
# Out:
# [5933.596568149862,
#  3506.8315374045624,
#  2926.280788015829,
#  2550.6668665746993,
#  2261.788879715885,
#  2054.1462111813116,
#  1866.0571938957085,
#  1699.4907436418957,
#  1568.8079270723351,
#  1448.21598535646]

# %% [markdown]
# n_clusters:int, default=8
# The number of clusters to form as well as the number of centroids to generate.
#
# n_ini:tint, default=10
# Number of time the k-means algorithm will be run with different centroid seeds. The final results will be the best output of n_init consecutive runs in terms of inertia.
#
# tol:float, default=1e-4
# Relative tolerance with regards to Frobenius norm of the difference in the cluster centers of two consecutive iterations to declare convergence.
#
# random_state:int, RandomState instance or None, default=None
# Determines random number generation for centroid initialization. Use an int to make the randomness deterministic.

# %%
plt.figure(figsize=(12,6))
plt.plot(range(1,11),inertia)
plt.title("Elbow method")
plt.xlabel("no of k")
plt.ylabel("inertia")
# Out:
# Text(0, 0.5, 'inertia')

# %%
kmeans = KMeans(n_clusters=3,
               init="k-means++", # default value
               tol = 1e-04, # default value
               random_state=32)

# fitting with our data X_scld
kmeans.fit(df_scaled) # passing the scaled data
# Out:
# KMeans(n_clusters=3, random_state=32)

# %%
kmeans.labels_
# Out:
# array([1, 1, 0, ..., 2, 1, 0], dtype=int32)

# %%
import joblib
joblib.dump(kmeans,'cluster_model.pkl')
# Out:
# ['cluster_model.pkl']

# %%
from sklearn.metrics import silhouette_score
silhouette_score(df_scaled,kmeans.labels_)
# Out:
# 0.372402419289504

# %%
from sklearn.cluster import DBSCAN
DB=DBSCAN()
DB.fit(df_scaled)
# Out:
# DBSCAN()

# %%
DB.labels_
# Out:
# array([0, 0, 0, ..., 0, 0, 0])

# %%
silhouette_score(df_scaled,DB.labels_)
# Out:
# 0.3436414886732004

# %%
from sklearn.cluster import AgglomerativeClustering
AGC=AgglomerativeClustering()
AGC.fit(df_scaled)
print(DB.labels_)
silhouette_score(df_scaled,DB.labels_)
# Out:
# [0 0 0 ... 0 0 0]
# 0.3436414886732004

# %%
df['cluster_labels']=kmeans.labels_
df.head(5)
# Out:
#        BALANCE  BALANCE_FREQUENCY  PURCHASES  ONEOFF_PURCHASES  \
# 0    40.900749           0.818182      95.40              0.00
# 1  3202.467416           0.909091       0.00              0.00
# 2  2495.148862           1.000000     773.17            773.17
# 3  1666.670542           0.636364    1499.00           1499.00
# 4   817.714335           1.000000      16.00             16.00
#
#    INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# 0                    95.4      0.000000             0.166667
# 1                     0.0   6442.945483             0.000000
# 2                     0.0      0.000000             1.000000
# 3                     0.0    205.788017             0.083333
# 4                     0.0      0.000000             0.083333
#
#    ONEOFF_PURCHASES_FREQUENCY  PURCHASES_INSTALLMENTS_FREQUENCY  \
# 0                    0.000000                          0.083333
# 1                    0.000000                          0.000000
# ...

# %%
scl_df=pd.DataFrame(df_scaled,columns=df.drop("cluster_labels",axis=1).columns)
scl_df["cluster_labels"]=kmeans.labels_
scl_df.head(5)
# Out:
#     BALANCE  BALANCE_FREQUENCY  PURCHASES  ONEOFF_PURCHASES  \
# 0  0.002148           0.818182   0.001945          0.000000
# 1  0.168169           0.909091   0.000000          0.000000
# 2  0.131026           1.000000   0.015766          0.018968
# 3  0.087521           0.636364   0.030567          0.036775
# 4  0.042940           1.000000   0.000326          0.000393
#
#    INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# 0                 0.00424      0.000000             0.166667
# 1                 0.00000      0.136685             0.000000
# 2                 0.00000      0.000000             1.000000
# 3                 0.00000      0.004366             0.083333
# 4                 0.00000      0.000000             0.083333
#
#    ONEOFF_PURCHASES_FREQUENCY  PURCHASES_INSTALLMENTS_FREQUENCY  \
# 0                    0.000000                          0.083333
# 1                    0.000000                          0.000000
# ...

# %%
from sklearn.decomposition import PCA
pca = PCA(n_components=2)

data4 = scl_df.drop('cluster_labels', axis=1)

pca_data = pca.fit_transform(data4)
pca_data
# Out:
# array([[-0.48226651, -0.09788507],
#        [-0.60871018, -0.01954664],
#        [ 0.3043492 ,  0.92107993],
#        ...,
#        [ 0.3605898 , -0.42183121],
#        [-0.6459293 , -0.20346505],
#        [-0.09440953,  0.40069715]])

# %%
pca.explained_variance_ratio_
# Out:
# array([0.49602563, 0.14056409])

# %%
pca_df = pd.DataFrame(pca_data, columns=['pca1', 'pca2'])
pca_df['labels'] = kmeans.labels_
pca_df
# Out:
#           pca1      pca2  labels
# 0    -0.482267 -0.097885       1
# 1    -0.608710 -0.019547       1
# 2     0.304349  0.921080       0
# 3    -0.588696 -0.005649       1
# 4    -0.554500  0.052608       1
# ...        ...       ...     ...
# 8944  0.647100 -0.462152       2
# 8945  0.550066 -0.406322       2
# 8946  0.360590 -0.421831       2
# 8947 -0.645929 -0.203465       1
# 8948 -0.094410  0.400697       0
#
# [8949 rows x 3 columns]

# %%
# plotting all the data
plt.figure(figsize=(12,6))
sns.scatterplot(x='pca1', y='pca2', data=pca_df, hue='labels')

# %%
df.to_csv("df_general_with_cluster_label.csv", index=False)

# %%
scl_df.to_csv("df_general_scaled_with_cluster_label.csv", index=False)

# %%
scl_df['cluster_labels'].value_counts()
# Out:
# 1    4723
# 2    2782
# 0    1444
# Name: cluster_labels, dtype: int64

# %%
polar = scl_df.groupby("cluster_labels").mean().reset_index()
polar
# Out:
#    cluster_labels   BALANCE  BALANCE_FREQUENCY  PURCHASES  ONEOFF_PURCHASES  \
# 0               0  0.101016           0.973724   0.065169          0.058686
# 1               1  0.089549           0.826392   0.006031          0.005715
# 2               2  0.059839           0.913838   0.021747          0.006594
#
#    INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# 0                0.035723      0.013969             0.893082
# 1                0.002800      0.028794             0.143219
# 2                0.035481      0.010673             0.870813
#
#    ONEOFF_PURCHASES_FREQUENCY  PURCHASES_INSTALLMENTS_FREQUENCY  \
# 0                    0.798337                          0.481322
# 1                    0.081542                          0.060573
# 2                    0.098518                          0.819770
#
#    CASH_ADVANCE_FREQUENCY  CASH_ADVANCE_TRX  PURCHASES_TRX  CREDIT_LIMIT  \
# 0                0.062324          0.018985       0.118183      0.222083
# ...

# %%
melt_df = pd.melt(polar, id_vars=['cluster_labels'])
melt_df
# Out:
#     cluster_labels                          variable     value
# 0                0                           BALANCE  0.101016
# 1                1                           BALANCE  0.089549
# 2                2                           BALANCE  0.059839
# 3                0                 BALANCE_FREQUENCY  0.973724
# 4                1                 BALANCE_FREQUENCY  0.826392
# 5                2                 BALANCE_FREQUENCY  0.913838
# 6                0                         PURCHASES  0.065169
# 7                1                         PURCHASES  0.006031
# 8                2                         PURCHASES  0.021747
# 9                0                  ONEOFF_PURCHASES  0.058686
# 10               1                  ONEOFF_PURCHASES  0.005715
# 11               2                  ONEOFF_PURCHASES  0.006594
# 12               0            INSTALLMENTS_PURCHASES  0.035723
# 13               1            INSTALLMENTS_PURCHASES  0.002800
# ...

# %%
import plotly.express as px
fig4 = px.line_polar(melt_df, r="value", theta="variable", color="cluster_labels", 
                     line_close=True,height=650,width=1100)
fig4.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...
